# %%
import os
import pandas as pd
import numpy as np
import warnings
import hdbscan

from hdbscan import validity
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from collections import Counter
from itertools import combinations

warnings.filterwarnings('ignore')

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
import os
import sys

svanoo_myanimelist_dataset_path = kagglehub.dataset_download('svanoo/myanimelist-dataset')

print('Data source import complete.')
# Out:
# Data source import complete.

# %% [markdown]
# ## CHECK THIS BLOCK AND UPDATE VALUES

# %%
animes_path = f'{svanoo_myanimelist_dataset_path}/anime.csv'
relations_path = f'{svanoo_myanimelist_dataset_path}/anime_anime.csv'
clusters_path = 'EFFNetClusteringResults'
clusters_file_type = '.csv'
top_animes_path = 'top_animes.csv'
top_relations_path = 'top_relations.csv'


relations_weight = 0.5
genres_weight = 0.5

TITLES_TO_TAKE = 2000
rec_thresthold = 2

animes = pd.read_csv(animes_path,sep="\t")
relations = pd.read_csv(relations_path,sep="\t")

# %%
cluster_files = []
for filename in os.listdir(clusters_path):
    if filename.endswith(clusters_file_type):
        cluster_files.append(filename)

# %%
animes["score_count"]= pd.to_numeric(animes["score_count"], errors='raise', downcast='float')
top_animes = animes.sort_values("score_count", ascending=False).head(TITLES_TO_TAKE)

top_ids = top_animes['anime_id'].tolist()

top_relations = relations[relations['animeA'].isin(top_ids) & relations['animeB'].isin(top_ids)]
top_relations = top_relations[top_relations['num_recommenders'] > rec_thresthold]

top_animes.to_csv(top_animes_path, index=False)
top_relations.to_csv(top_relations_path, index=False)

# %%
def cluster_test(clusters, relations):
    # Step 1: Get cluster for animeA
    relations_clusterA = relations.merge(
        clusters, 
        left_on='animeA', 
        right_on='anime_id', 
        how='inner'
    ).rename(columns={'cluster': 'cluster_A'}).drop(columns=['anime_id'])

    # Step 2: Get cluster for animeB
    relations_both_clusters = relations_clusterA.merge(
        clusters, 
        left_on='animeB', 
        right_on='anime_id', 
        how='inner'
    ).rename(columns={'cluster': 'cluster_B'}).drop(columns=['anime_id'])

    # Step 3: Calculate statistics
    total_valid_relations = len(relations_both_clusters)
    same_cluster_count = (relations_both_clusters['cluster_A'] == relations_both_clusters['cluster_B']).sum()
    percentage = (same_cluster_count / total_valid_relations) * 100

    print(f"Original relations: {len(relations)}")
    print(f"Valid relations (both animes in clusters): {total_valid_relations}")
    print(f"Relations within same cluster: {same_cluster_count}")
    print(f"Percentage within same cluster: {percentage:.2f}%")

    return percentage

# %%
def genre_test(clusters, animes):
    # Create mappings
    anime_to_cluster = dict(zip(clusters['anime_id'], clusters['cluster']))
    anime_to_genres = {}

    # Parse genres for each anime
    for _, row in animes.iterrows():
        anime_id = row['anime_id']
        genres = set(row['genres'].split('|')) if pd.notna(row['genres']) else set()
        anime_to_genres[anime_id] = genres

    # Function to calculate Jaccard similarity
    def jaccard_similarity(set1, set2):
        if len(set1) == 0 and len(set2) == 0:
            return 1.0  # Both empty sets are considered identical
        intersection = len(set1.intersection(set2))
        union = len(set1.union(set2))
        return intersection / union if union > 0 else 0.0

    # Group animes by cluster
    cluster_to_animes = {}
    for anime_id, cluster in anime_to_cluster.items():
        if anime_id in anime_to_genres:  # Only include animes that have genre data
            if cluster not in cluster_to_animes:
                cluster_to_animes[cluster] = []
            cluster_to_animes[cluster].append(anime_id)

    # Calculate average Jaccard similarity for each cluster
    cluster_similarities = {}

    for cluster, anime_list in cluster_to_animes.items():
        if len(anime_list) < 2:
            cluster_similarities[cluster] = None  # Can't calculate similarity with < 2 animes
            continue
        
        similarities = []
        for anime1, anime2 in combinations(anime_list, 2):
            genres1 = anime_to_genres[anime1]
            genres2 = anime_to_genres[anime2]
            similarity = jaccard_similarity(genres1, genres2)
            similarities.append(similarity)
        
        cluster_similarities[cluster] = sum(similarities) / len(similarities)

    # Display results
    # print("Average Jaccard similarity by cluster:")
    valid_clusters = {k: v for k, v in cluster_similarities.items() if v is not None}

    # for cluster, avg_similarity in valid_clusters.items():
    #     anime_count = len(cluster_to_animes[cluster])
    #     pair_count = len(list(combinations(cluster_to_animes[cluster], 2)))
    #     print(f"Cluster {cluster}: {avg_similarity:.4f} (from {pair_count} pairs, {anime_count} animes)")

    # Overall average across all clusters
    if valid_clusters:
        overall_average = sum(valid_clusters.values()) / len(valid_clusters) * 100
        print(f"Overall average Jaccard similarity: {overall_average:.2f}%")
        print(f"Calculated across {len(valid_clusters)} clusters")
    # else:
    #     print("No valid clusters found")

    return overall_average

# %%
def calculate_anime_clustering_fidelity(cluster_file_path, anime_file_path, relations_file_path,
                                      content_weight=0.4, engagement_weight=0.3, 
                                      size_weight=0.2, metadata_weight=0.1):
    """
    Calculate clustering fidelity score for anime clusters.
    
    Parameters:
    -----------
    cluster_file_path : str
        Path to CSV with columns: anime_id, cluster
    anime_file_path : str 
        Path to anime.csv with metadata
    relations_file_path : str
        Path to anime relations CSV with recommendation data
    content_weight : float (default 0.4)
        Weight for content similarity component
    engagement_weight : float (default 0.3)
        Weight for user engagement component  
    size_weight : float (default 0.2)
        Weight for size balance component
    metadata_weight : float (default 0.1)
        Weight for metadata consistency component
        
    Returns:
    --------
    dict: Detailed breakdown of fidelity scores and final combined score
    """

    print("📊 Loading data files...")

    # Load data - PROPERLY parse CSV with quoted fields
    clusters_df = pd.read_csv(cluster_file_path)
    anime_df = pd.read_csv(anime_file_path, quotechar='"', escapechar='\\')  # Proper CSV parsing
    relations_df = pd.read_csv(relations_file_path)

    # Debug: Check if we're getting the right columns now
    # print(f"📋 Anime columns found: {list(anime_df.columns)}")

    # Merge cluster data with anime metadata
    clustered_anime = clusters_df.merge(anime_df, left_on='anime_id', right_on='anime_id', how='left')
    
    print(f"✅ Loaded {len(clustered_anime)} anime across {clustered_anime['cluster'].nunique()} clusters")
    
    # ===== COMPONENT 1: CONTENT SIMILARITY (40%) =====
    #print("🎬 Calculating content similarity...")
    content_score = calculate_content_similarity(clustered_anime)
    
    # ===== COMPONENT 2: USER ENGAGEMENT (30%) =====
    #print("👥 Calculating user engagement...")
    engagement_score = calculate_user_engagement(clustered_anime, relations_df)
    
    # ===== COMPONENT 3: SIZE BALANCE (20%) =====
    #print("⚖️ Calculating size balance...")
    size_score = calculate_size_balance_simpsons(clustered_anime)
    
    # ===== COMPONENT 4: METADATA CONSISTENCY (10%) =====
    #print("📋 Calculating metadata consistency...")
    metadata_score = calculate_metadata_consistency(clustered_anime)
    
    # ===== FINAL COMBINED SCORE =====
    final_score = (content_weight * content_score + 
                   engagement_weight * engagement_score +
                   size_weight * size_score + 
                   metadata_weight * metadata_score)
    
    results = {
        'final_fidelity_score': final_score,
        'component_scores': {
            'content_similarity': content_score,
            'user_engagement': engagement_score, 
            'size_balance': size_score,
            'metadata_consistency': metadata_score
        },
        'component_weights': {
            'content_weight': content_weight,
            'engagement_weight': engagement_weight,
            'size_weight': size_weight, 
            'metadata_weight': metadata_weight
        },
        'cluster_stats': {
            'total_anime': len(clustered_anime),
            'num_clusters': clustered_anime['cluster'].nunique(),
            'avg_cluster_size': len(clustered_anime) / clustered_anime['cluster'].nunique(),
            'largest_cluster_size': clustered_anime['cluster'].value_counts().max(),
            'smallest_cluster_size': clustered_anime['cluster'].value_counts().min()
        }
    }
    
    #print(f"\n🎯 FINAL FIDELITY SCORE: {final_score:.3f}")
    return results

def calculate_content_similarity(clustered_anime):
    """Calculate content-based similarity within clusters using improved metrics."""
    
    # Verify imports are working
    try:
        from sklearn.metrics import calinski_harabasz_score, davies_bouldin_score
    except ImportError as e:
        print(f"   ❌ Import error: {e}")
        # Fallback to just silhouette
        return calculate_content_similarity_fallback(clustered_anime)
    
    # Create feature matrix from anime metadata
    features = []
    
    # Numerical features (normalized) - updated with correct column names
    numerical_cols = ['score', 'score_count', 'score_rank', 'popularity_rank', 
                     'members_count', 'favorites_count', 'num_episodes',
                     'watching_count', 'completed_count', 'on_hold_count', 
                     'dropped_count', 'plan_to_watch_count', 'total_count']
    
    for col in numerical_cols:
        if col in clustered_anime.columns:
            # Fill NaN and normalize
            values = pd.to_numeric(clustered_anime[col], errors='coerce').fillna(0)
            if values.std() > 0:  # Avoid division by zero
                normalized = (values - values.mean()) / values.std()
                features.append(normalized.values.reshape(-1, 1))
    
    # Categorical features (one-hot encoded) - updated with correct column names  
    categorical_cols = ['type', 'source_type', 'status', 'season']
    
    for col in categorical_cols:
        if col in clustered_anime.columns:
            # Simple one-hot encoding
            unique_vals = clustered_anime[col].fillna('Unknown').unique()
            for val in unique_vals:
                feature_col = (clustered_anime[col].fillna('Unknown') == val).astype(int)
                features.append(feature_col.values.reshape(-1, 1))
    
    # Genre similarity (Jaccard-based) - pipe-delimited
    if 'genres' in clustered_anime.columns:
        genre_features = calculate_genre_features(clustered_anime)
        if genre_features is not None:
            features.append(genre_features)
    
    # Studio similarity - pipe-delimited
    if 'studios' in clustered_anime.columns:
        studio_features = calculate_studio_features(clustered_anime)
        if studio_features is not None:
            features.append(studio_features)
    
    if not features:
        print("⚠️ No valid features found for content similarity")
        return 0.5  # Neutral score
    
    # Combine all features
    X = np.hstack(features)
    
    # Calculate improved clustering validity metrics
    try:
        labels = clustered_anime['cluster'].values
        if len(np.unique(labels)) < 2:
            return 0.0  # Single cluster gets 0 score
        
        # Method 1: Try DBCV (Density-Based Cluster Validation) - BEST
        dbcv_score = calculate_dbcv_score(X, labels)
        if dbcv_score is not None and not np.isnan(dbcv_score):
            print(f"   📊 Using DBCV score: {dbcv_score:.3f}")
            return max(0, dbcv_score)  # DBCV already in [0,1] range, higher = better
        
        # Method 2: Calinski-Harabasz Index (higher = better)
        try:
            ch_score = calinski_harabasz_score(X, labels)
            # Normalize CH score to roughly [0,1] range
            # Typical CH scores range from 10-1000+, so we use log normalization
            normalized_ch = min(1.0, np.log10(max(1, ch_score)) / 3.0)  # log10(1000) = 3
            print(f"   📊 Using Calinski-Harabasz score: {ch_score:.1f} → normalized: {normalized_ch:.3f}")
            return normalized_ch
        except Exception as e:
            print(f"   ⚠️ Calinski-Harabasz failed: {e}")
        
        # Method 3: Davies-Bouldin Index (lower = better, so we invert it)
        try:
            db_score = davies_bouldin_score(X, labels)
            # DB typically ranges from 0.5-3+, lower is better
            # Convert to [0,1] where higher = better
            normalized_db = max(0, 1 - (db_score / 3.0))
            print(f"   📊 Using Davies-Bouldin score: {db_score:.3f} → normalized: {normalized_db:.3f}")
            return normalized_db
        except Exception as e:
            print(f"   ⚠️ Davies-Bouldin failed: {e}")
        
        # Method 4: Fallback to Silhouette (worst option)
        try:
            sil_score = silhouette_score(X, labels)
            normalized_sil = (sil_score + 1) / 2  # Convert from [-1,1] to [0,1]
            print(f"   📊 Using Silhouette score: {sil_score:.3f} → normalized: {normalized_sil:.3f}")
            return normalized_sil
        except Exception as e:
            print(f"   ⚠️ All metrics failed: {e}")
            return 0.5
        
    except Exception as e:
        print(f"⚠️ Error calculating content similarity: {e}")
        return 0.5

def calculate_content_similarity_fallback(clustered_anime):
    """Fallback function with just silhouette score if imports fail."""
    print("   📉 Using fallback silhouette score only")
    
    # Simplified feature creation and silhouette calculation
    # [Same feature creation code as before but simpler]
    features = []
    
    # Just use numerical features for fallback
    numerical_cols = ['score', 'score_count', 'score_rank', 'popularity_rank', 
                     'members_count', 'favorites_count', 'num_episodes']
    
    for col in numerical_cols:
        if col in clustered_anime.columns:
            values = pd.to_numeric(clustered_anime[col], errors='coerce').fillna(0)
            if values.std() > 0:
                normalized = (values - values.mean()) / values.std()
                features.append(normalized.values.reshape(-1, 1))
    
    if not features:
        return 0.5
    
    X = np.hstack(features)
    labels = clustered_anime['cluster'].values
    
    try:
        sil_score = silhouette_score(X, labels)
        return (sil_score + 1) / 2
    except:
        return 0.5

def calculate_dbcv_score(X, labels):
    """Calculate DBCV (Density-Based Cluster Validation) score with better error handling."""
    try:
        import hdbscan
        from hdbscan import validity
        
        # DBCV requires dense matrix and specific label format
        if hasattr(X, 'toarray'):
            X_dense = X.toarray()
        else:
            X_dense = np.array(X)
        
        # Ensure we have valid data
        if X_dense.shape[0] < 2:
            print("   ⚠️ DBCV: Not enough data points")
            return None
            
        # Check for valid clusters (DBCV needs at least 2 clusters with 2+ points each)
        unique_labels, counts = np.unique(labels, return_counts=True)
        valid_clusters = counts >= 2  # Clusters with at least 2 points
        
        if np.sum(valid_clusters) < 2:
            print("   ⚠️ DBCV: Need at least 2 clusters with 2+ points each")
            return None
        
        # Filter to only valid clusters
        valid_cluster_ids = unique_labels[valid_clusters]
        valid_mask = np.isin(labels, valid_cluster_ids)
        
        if np.sum(valid_mask) < 4:  # Need at least 4 total points in valid clusters
            print("   ⚠️ DBCV: Not enough points in valid clusters")
            return None
        
        X_filtered = X_dense[valid_mask]
        labels_filtered = labels[valid_mask]
        
        # Remap labels to be consecutive starting from 0
        label_map = {old_label: new_label for new_label, old_label in enumerate(np.unique(labels_filtered))}
        mapped_labels = np.array([label_map[label] for label in labels_filtered])
        
        # Ensure proper data types
        X_final = X_filtered.astype(np.float64)
        labels_final = mapped_labels.astype(np.int32)
        
        # Additional safety checks
        if X_final.shape[1] == 0:
            print("   ⚠️ DBCV: No features in data")
            return None
            
        if np.any(np.isnan(X_final)) or np.any(np.isinf(X_final)):
            print("   ⚠️ DBCV: Data contains NaN or Inf values")
            return None
        
        # Calculate DBCV with error handling
        try:
            dbcv = validity.validity_index(X_final, labels_final)
            # Check if result is valid
            if dbcv is None or np.isnan(dbcv) or np.isinf(dbcv):
                print("   ⚠️ DBCV: Invalid result returned")
                return None
                
            print(f"   ✅ DBCV calculated successfully: {dbcv:.3f}")
            return dbcv
            
        except (ValueError, IndexError, RuntimeError) as e:
            print(f"   ⚠️ DBCV calculation error: {e}")
            return None
        
    except ImportError:
        print("   📦 HDBSCAN not installed. Install with: pip install hdbscan")
        return None
    except Exception as e:
        print(f"   ⚠️ DBCV setup failed: {e}")
        return None

def calculate_genre_features(clustered_anime):
    """Create genre feature matrix using multi-hot encoding."""
    try:
        # Get all unique genres (split on | not ,)
        all_genres = set()
        for genres_str in clustered_anime['genres'].dropna():
            if isinstance(genres_str, str):
                genres = [g.strip() for g in genres_str.split('|')]
                all_genres.update(genres)
        
        all_genres = sorted(list(all_genres))
        
        # Create multi-hot encoding
        genre_matrix = []
        for genres_str in clustered_anime['genres'].fillna(''):
            row = [0] * len(all_genres)
            if isinstance(genres_str, str) and genres_str:
                genres = [g.strip() for g in genres_str.split('|')]
                for genre in genres:
                    if genre in all_genres:
                        idx = all_genres.index(genre)
                        row[idx] = 1
            genre_matrix.append(row)
        
        return np.array(genre_matrix)
    except:
        return None

def calculate_studio_features(clustered_anime):
    """Create studio feature matrix."""
    try:
        # Get all unique studios (check if pipe-delimited too)
        all_studios = set()
        for studios_str in clustered_anime['studios'].dropna():
            if isinstance(studios_str, str):
                # Try pipe delimiter first, then comma fallback
                if '|' in studios_str:
                    studios = [s.strip() for s in studios_str.split('|')]
                else:
                    studios = [s.strip() for s in studios_str.split(',')]
                all_studios.update(studios)
        
        all_studios = sorted(list(all_studios))
        
        # Create multi-hot encoding
        studio_matrix = []
        for studios_str in clustered_anime['studios'].fillna(''):
            row = [0] * len(all_studios)
            if isinstance(studios_str, str) and studios_str:
                # Try pipe delimiter first, then comma fallback
                if '|' in studios_str:
                    studios = [s.strip() for s in studios_str.split('|')]
                else:
                    studios = [s.strip() for s in studios_str.split(',')]
                for studio in studios:
                    if studio in all_studios:
                        idx = all_studios.index(studio)
                        row[idx] = 1
            studio_matrix.append(row)
        
        return np.array(studio_matrix)
    except:
        return None

def calculate_user_engagement(clustered_anime, relations_df):
    """Calculate user engagement score using recommendation data."""
    
    try:
        # Filter for actual recommendations (not just relations)
        recommendations = relations_df[relations_df['recommendation'] == 1].copy()
        
        if len(recommendations) == 0:
            print("⚠️ No recommendation data found")
            return 0.5
        
        # Get anime in our clusters
        clustered_ids = set(clustered_anime['anime_id'].values)
        
        # Filter recommendations to only include clustered anime
        recs_filtered = recommendations[
            (recommendations['animeA'].isin(clustered_ids)) & 
            (recommendations['animeB'].isin(clustered_ids))
        ]
        
        if len(recs_filtered) == 0:
            print("⚠️ No recommendations found between clustered anime")
            return 0.5
        
        # Create cluster mapping
        cluster_map = dict(zip(clustered_anime['anime_id'], clustered_anime['cluster']))
        
        # Calculate same-cluster recommendation rate
        total_recommendations = 0
        same_cluster_recommendations = 0
        recommendation_strength_sum = 0
        
        for _, row in recs_filtered.iterrows():
            anime_a, anime_b = row['animeA'], row['animeB']
            num_recommenders = row.get('num_recommenders', 1)
            
            if anime_a in cluster_map and anime_b in cluster_map:
                total_recommendations += 1
                
                if cluster_map[anime_a] == cluster_map[anime_b]:
                    same_cluster_recommendations += 1
                    # Weight by recommendation strength
                    recommendation_strength_sum += num_recommenders
        
        if total_recommendations == 0:
            return 0.5
        
        # Base score: percentage of recommendations within same cluster
        base_score = same_cluster_recommendations / total_recommendations
        
        # Bonus for recommendation strength
        if same_cluster_recommendations > 0:
            avg_strength = recommendation_strength_sum / same_cluster_recommendations
            strength_bonus = min(0.1, avg_strength / 100)  # Max 10% bonus
            base_score += strength_bonus
        
        return min(1.0, base_score)  # Cap at 1.0
        
    except Exception as e:
        print(f"⚠️ Error calculating user engagement: {e}")
        return 0.5


def cluster_balance_score(df):
    """
    Calculate cluster balance score from dataframe with anime_id and cluster columns.
    
    Args:
        df: DataFrame with 'anime_id' and 'cluster' columns
    
    Returns:
        float: Balance score (0-1, higher = better balance)
    """
    cluster_sizes = df['cluster'].value_counts().values
    proportions = cluster_sizes / len(df)
    
    # Simpson's diversity
    simpson = 1 - np.sum(proportions**2)
    
    # Penalties
    cr1 = np.max(proportions)  # Largest cluster
    cr3 = np.sum(np.sort(proportions)[-3:])  # Top 3 clusters
    
    penalties = 0
    if cr1 > 0.25:
        penalties += (cr1 - 0.25) * 2
    if cr3 > 0.60:
        penalties += (cr3 - 0.60) * 1.5
    if len(cluster_sizes) < 4:
        penalties += (4 - len(cluster_sizes)) * 0.2
    
    return max(0, simpson - penalties)

def calculate_size_balance_simpsons(clustered_anime):
    """Calculate size balance score (penalizes giant clusters)."""
    
    cluster_counts = clustered_anime['cluster'].value_counts()
    
    # Method 1: Standard deviation penalty
    mean_size = cluster_counts.mean()
    std_size = cluster_counts.std()
    
    if mean_size == 0:
        return 0.0
    
    # Balance score: lower std relative to mean = better balance
    balance_score = max(0, 1 - (std_size / mean_size))
    
    # Method 2: Giant cluster penalty
    total_anime = len(clustered_anime)
    largest_cluster_pct = cluster_counts.max() / total_anime
    
    # Penalize if largest cluster > 40% of total
    giant_penalty = 0
    if largest_cluster_pct > 0.4:
        giant_penalty = (largest_cluster_pct - 0.4) * 2  # Linear penalty
    
    final_score = max(0, balance_score - giant_penalty)
    
    return final_score

def calculate_metadata_consistency(clustered_anime):
    """Calculate metadata consistency within clusters."""
    
    consistency_scores = []
    
    # Check consistency for each cluster
    for cluster_id in clustered_anime['cluster'].unique():
        cluster_data = clustered_anime[clustered_anime['cluster'] == cluster_id]
        
        if len(cluster_data) < 2:
            consistency_scores.append(1.0)  # Single anime clusters are perfectly consistent
            continue
        
        cluster_consistency = []
        
        # Type consistency (TV, Movie, etc.)
        if 'type' in cluster_data.columns:
            type_counts = cluster_data['type'].value_counts()
            type_consistency = type_counts.max() / len(cluster_data)
            cluster_consistency.append(type_consistency)
        
        # Season consistency (for seasonal anime)
        if 'season' in cluster_data.columns:
            season_counts = cluster_data['season'].dropna().value_counts()
            if len(season_counts) > 0:
                season_consistency = season_counts.max() / len(cluster_data.dropna(subset=['season']))
                cluster_consistency.append(season_consistency)
        
        # Studio consistency
        if 'studios' in cluster_data.columns:
            # For multi-studio anime, check if studios overlap
            studio_overlap = calculate_studio_overlap(cluster_data['studios'])
            cluster_consistency.append(studio_overlap)
        
        # Score range consistency (similar quality anime should cluster)
        if 'score' in cluster_data.columns:
            scores = cluster_data['score'].dropna()
            if len(scores) > 1:
                score_std = scores.std()
                # Normalize by overall score range (assume 1-10 scale)
                score_consistency = max(0, 1 - (score_std / 2.5))  # 2.5 = reasonable std for 10-point scale
                cluster_consistency.append(score_consistency)
        
        if cluster_consistency:
            consistency_scores.append(np.mean(cluster_consistency))
        else:
            consistency_scores.append(0.5)  # Neutral score if no consistency measures
    
    return np.mean(consistency_scores) if consistency_scores else 0.5

def calculate_studio_overlap(studio_series):
    """Calculate studio overlap within a cluster."""
    try:
        all_studios = []
        for studios_str in studio_series.dropna():
            if isinstance(studios_str, str):
                # Handle pipe delimiters for studios too
                if '|' in studios_str:
                    studios = [s.strip() for s in studios_str.split('|')]
                else:
                    studios = [s.strip() for s in studios_str.split(',')]
                all_studios.extend(studios)
        
        if not all_studios:
            return 0.5
        
        studio_counts = Counter(all_studios)
        most_common_count = studio_counts.most_common(1)[0][1] if studio_counts else 0
        
        # Consistency = how often the most common studio appears
        return most_common_count / len(studio_series.dropna()) if len(studio_series.dropna()) > 0 else 0.5
        
    except:
        return 0.5

# %%
max_score = 0
max_score_path = ""

for file in cluster_files:    
    cluster_file_path = os.path.join(clusters_path, file)

    results = calculate_anime_clustering_fidelity(
        cluster_file_path=cluster_file_path,
        anime_file_path=top_animes_path,
        relations_file_path=top_relations_path,
        content_weight=0.4,
        engagement_weight=0.3,  # Reduced from 0.3
        size_weight=0.2,        # Increased from 0.2  
        metadata_weight=0.1
    )
    
    if results['final_fidelity_score'] > max_score:
        max_score = results['final_fidelity_score']
        max_score_path = cluster_file_path

    print("\n" + "="*50)
    print(f"📊 CLUSTERING FIDELITY RESULTS FOR {file}" )
    print("="*50)
    
    print(f"\n🎯 Final Fidelity Score: {results['final_fidelity_score']:.3f}")
    
    print(f"\n📋 Component Breakdown:")
    
    # Map component names to weight names
    component_weight_map = {
        'content_similarity': 'content_weight',
        'user_engagement': 'engagement_weight', 
        'size_balance': 'size_weight',
        'metadata_consistency': 'metadata_weight'
    }
    
    for component, score in results['component_scores'].items():
        weight_key = component_weight_map[component]
        weight = results['component_weights'][weight_key]
        contribution = weight * score
        print(f"   {component.replace('_', ' ').title()}: {score:.3f} (weight: {weight:.1f}, contribution: {contribution:.3f})")
    
    print(f"\n📊 Cluster Statistics:")
    for stat, value in results['cluster_stats'].items():
        print(f"   {stat.replace('_', ' ').title()}: {value}")
    
print("\n" + "="*50)
print(f"🏆 HIGHEST FIDELITY SCORE: {max_score:.3}")
print(f"   Path: {max_score_path}")
print("="*50)
# Out:
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 10 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.7 → normalized: 0.077
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_10_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.228
#
# 📋 Component Breakdown:
#    Content Similarity: 0.077 (weight: 0.4, contribution: 0.031)
#    User Engagement: 0.209 (weight: 0.3, contribution: 0.063)
#    Size Balance: 0.482 (weight: 0.2, contribution: 0.096)
#    Metadata Consistency: 0.388 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 10
#    Avg Cluster Size: 200.0
#    Largest Cluster Size: 398
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 11 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.7 → normalized: 0.079
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_11_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.222
#
# 📋 Component Breakdown:
#    Content Similarity: 0.079 (weight: 0.4, contribution: 0.032)
#    User Engagement: 0.199 (weight: 0.3, contribution: 0.060)
#    Size Balance: 0.458 (weight: 0.2, contribution: 0.092)
#    Metadata Consistency: 0.387 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 11
#    Avg Cluster Size: 181.8181818181818
#    Largest Cluster Size: 398
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 12 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.7 → normalized: 0.074
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_12_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.205
#
# 📋 Component Breakdown:
#    Content Similarity: 0.074 (weight: 0.4, contribution: 0.029)
#    User Engagement: 0.198 (weight: 0.3, contribution: 0.059)
#    Size Balance: 0.387 (weight: 0.2, contribution: 0.077)
#    Metadata Consistency: 0.388 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 12
#    Avg Cluster Size: 166.66666666666666
#    Largest Cluster Size: 398
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 13 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.7 → normalized: 0.079
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_13_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.195
#
# 📋 Component Breakdown:
#    Content Similarity: 0.079 (weight: 0.4, contribution: 0.032)
#    User Engagement: 0.192 (weight: 0.3, contribution: 0.057)
#    Size Balance: 0.332 (weight: 0.2, contribution: 0.066)
#    Metadata Consistency: 0.390 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 13
#    Avg Cluster Size: 153.84615384615384
#    Largest Cluster Size: 398
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 14 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.6 → normalized: 0.072
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_14_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.182
#
# 📋 Component Breakdown:
#    Content Similarity: 0.072 (weight: 0.4, contribution: 0.029)
#    User Engagement: 0.184 (weight: 0.3, contribution: 0.055)
#    Size Balance: 0.294 (weight: 0.2, contribution: 0.059)
#    Metadata Consistency: 0.390 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 14
#    Avg Cluster Size: 142.85714285714286
#    Largest Cluster Size: 398
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 15 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.6 → normalized: 0.072
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_15_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.172
#
# 📋 Component Breakdown:
#    Content Similarity: 0.072 (weight: 0.4, contribution: 0.029)
#    User Engagement: 0.183 (weight: 0.3, contribution: 0.055)
#    Size Balance: 0.245 (weight: 0.2, contribution: 0.049)
#    Metadata Consistency: 0.389 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 15
#    Avg Cluster Size: 133.33333333333334
#    Largest Cluster Size: 398
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 16 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.6 → normalized: 0.070
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_16_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.192
#
# 📋 Component Breakdown:
#    Content Similarity: 0.070 (weight: 0.4, contribution: 0.028)
#    User Engagement: 0.171 (weight: 0.3, contribution: 0.051)
#    Size Balance: 0.369 (weight: 0.2, contribution: 0.074)
#    Metadata Consistency: 0.391 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 16
#    Avg Cluster Size: 125.0
#    Largest Cluster Size: 283
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 17 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.6 → normalized: 0.066
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_17_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.199
#
# 📋 Component Breakdown:
#    Content Similarity: 0.066 (weight: 0.4, contribution: 0.027)
#    User Engagement: 0.160 (weight: 0.3, contribution: 0.048)
#    Size Balance: 0.429 (weight: 0.2, contribution: 0.086)
#    Metadata Consistency: 0.390 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 17
#    Avg Cluster Size: 117.6470588235294
#    Largest Cluster Size: 283
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 18 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.5 → normalized: 0.061
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_18_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.216
#
# 📋 Component Breakdown:
#    Content Similarity: 0.061 (weight: 0.4, contribution: 0.024)
#    User Engagement: 0.153 (weight: 0.3, contribution: 0.046)
#    Size Balance: 0.535 (weight: 0.2, contribution: 0.107)
#    Metadata Consistency: 0.390 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 18
#    Avg Cluster Size: 111.11111111111111
#    Largest Cluster Size: 267
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 19 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.5 → normalized: 0.059
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_19_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.205
#
# 📋 Component Breakdown:
#    Content Similarity: 0.059 (weight: 0.4, contribution: 0.023)
#    User Engagement: 0.150 (weight: 0.3, contribution: 0.045)
#    Size Balance: 0.487 (weight: 0.2, contribution: 0.097)
#    Metadata Consistency: 0.391 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 19
#    Avg Cluster Size: 105.26315789473684
#    Largest Cluster Size: 267
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 1 clusters
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_1_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.337
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.373 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 1
#    Avg Cluster Size: 2000.0
#    Largest Cluster Size: 2000
#    Smallest Cluster Size: 2000
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 20 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.5 → normalized: 0.057
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_20_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.200
#
# 📋 Component Breakdown:
#    Content Similarity: 0.057 (weight: 0.4, contribution: 0.023)
#    User Engagement: 0.148 (weight: 0.3, contribution: 0.044)
#    Size Balance: 0.469 (weight: 0.2, contribution: 0.094)
#    Metadata Consistency: 0.391 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 20
#    Avg Cluster Size: 100.0
#    Largest Cluster Size: 267
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 21 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.4 → normalized: 0.053
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_21_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.221
#
# 📋 Component Breakdown:
#    Content Similarity: 0.053 (weight: 0.4, contribution: 0.021)
#    User Engagement: 0.135 (weight: 0.3, contribution: 0.040)
#    Size Balance: 0.604 (weight: 0.2, contribution: 0.121)
#    Metadata Consistency: 0.390 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 21
#    Avg Cluster Size: 95.23809523809524
#    Largest Cluster Size: 174
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 22 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.5 → normalized: 0.055
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_22_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.218
#
# 📋 Component Breakdown:
#    Content Similarity: 0.055 (weight: 0.4, contribution: 0.022)
#    User Engagement: 0.130 (weight: 0.3, contribution: 0.039)
#    Size Balance: 0.592 (weight: 0.2, contribution: 0.118)
#    Metadata Consistency: 0.390 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 22
#    Avg Cluster Size: 90.9090909090909
#    Largest Cluster Size: 174
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 23 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.4 → normalized: 0.050
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_23_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.224
#
# 📋 Component Breakdown:
#    Content Similarity: 0.050 (weight: 0.4, contribution: 0.020)
#    User Engagement: 0.128 (weight: 0.3, contribution: 0.038)
#    Size Balance: 0.635 (weight: 0.2, contribution: 0.127)
#    Metadata Consistency: 0.390 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 23
#    Avg Cluster Size: 86.95652173913044
#    Largest Cluster Size: 156
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 24 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.4 → normalized: 0.046
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_24_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.226
#
# 📋 Component Breakdown:
#    Content Similarity: 0.046 (weight: 0.4, contribution: 0.018)
#    User Engagement: 0.125 (weight: 0.3, contribution: 0.037)
#    Size Balance: 0.653 (weight: 0.2, contribution: 0.131)
#    Metadata Consistency: 0.391 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 24
#    Avg Cluster Size: 83.33333333333333
#    Largest Cluster Size: 156
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 25 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.4 → normalized: 0.045
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_25_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.228
#
# 📋 Component Breakdown:
#    Content Similarity: 0.045 (weight: 0.4, contribution: 0.018)
#    User Engagement: 0.123 (weight: 0.3, contribution: 0.037)
#    Size Balance: 0.668 (weight: 0.2, contribution: 0.134)
#    Metadata Consistency: 0.392 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 25
#    Avg Cluster Size: 80.0
#    Largest Cluster Size: 156
#    Smallest Cluster Size: 41
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 2 clusters
#    ✅ DBCV calculated successfully: -0.765
#    📊 Using DBCV score: -0.765
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_2_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.330
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 0.975 (weight: 0.3, contribution: 0.293)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.374 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 2
#    Avg Cluster Size: 1000.0
#    Largest Cluster Size: 1860
#    Smallest Cluster Size: 140
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 3 clusters
#    ✅ DBCV calculated successfully: -0.944
#    📊 Using DBCV score: -0.944
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_3_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.249
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 0.705 (weight: 0.3, contribution: 0.211)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.378 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 3
#    Avg Cluster Size: 666.6666666666666
#    Largest Cluster Size: 1530
#    Smallest Cluster Size: 140
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 4 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 2.1 → normalized: 0.105
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_4_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.286
#
# 📋 Component Breakdown:
#    Content Similarity: 0.105 (weight: 0.4, contribution: 0.042)
#    User Engagement: 0.686 (weight: 0.3, contribution: 0.206)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.384 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 4
#    Avg Cluster Size: 500.0
#    Largest Cluster Size: 1530
#    Smallest Cluster Size: 140
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 5 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 2.3 → normalized: 0.119
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_5_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.243
#
# 📋 Component Breakdown:
#    Content Similarity: 0.119 (weight: 0.4, contribution: 0.047)
#    User Engagement: 0.412 (weight: 0.3, contribution: 0.124)
#    Size Balance: 0.167 (weight: 0.2, contribution: 0.033)
#    Metadata Consistency: 0.382 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 5
#    Avg Cluster Size: 400.0
#    Largest Cluster Size: 767
#    Smallest Cluster Size: 140
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 6 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 2.0 → normalized: 0.102
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_6_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.235
#
# 📋 Component Breakdown:
#    Content Similarity: 0.102 (weight: 0.4, contribution: 0.041)
#    User Engagement: 0.355 (weight: 0.3, contribution: 0.106)
#    Size Balance: 0.250 (weight: 0.2, contribution: 0.050)
#    Metadata Consistency: 0.382 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 6
#    Avg Cluster Size: 333.3333333333333
#    Largest Cluster Size: 767
#    Smallest Cluster Size: 140
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 7 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 2.0 → normalized: 0.103
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_7_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.257
#
# 📋 Component Breakdown:
#    Content Similarity: 0.103 (weight: 0.4, contribution: 0.041)
#    User Engagement: 0.261 (weight: 0.3, contribution: 0.078)
#    Size Balance: 0.495 (weight: 0.2, contribution: 0.099)
#    Metadata Consistency: 0.382 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 7
#    Avg Cluster Size: 285.7142857142857
#    Largest Cluster Size: 495
#    Smallest Cluster Size: 140
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 8 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.8 → normalized: 0.087
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_8_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.242
#
# 📋 Component Breakdown:
#    Content Similarity: 0.087 (weight: 0.4, contribution: 0.035)
#    User Engagement: 0.244 (weight: 0.3, contribution: 0.073)
#    Size Balance: 0.478 (weight: 0.2, contribution: 0.096)
#    Metadata Consistency: 0.384 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 8
#    Avg Cluster Size: 250.0
#    Largest Cluster Size: 459
#    Smallest Cluster Size: 97
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 9 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.7 → normalized: 0.076
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_average_9_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.247
#
# 📋 Component Breakdown:
#    Content Similarity: 0.076 (weight: 0.4, contribution: 0.030)
#    User Engagement: 0.217 (weight: 0.3, contribution: 0.065)
#    Size Balance: 0.567 (weight: 0.2, contribution: 0.113)
#    Metadata Consistency: 0.383 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 9
#    Avg Cluster Size: 222.22222222222223
#    Largest Cluster Size: 398
#    Smallest Cluster Size: 97
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 10 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.2 → normalized: 0.024
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_10_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.225
#
# 📋 Component Breakdown:
#    Content Similarity: 0.024 (weight: 0.4, contribution: 0.010)
#    User Engagement: 0.190 (weight: 0.3, contribution: 0.057)
#    Size Balance: 0.602 (weight: 0.2, contribution: 0.120)
#    Metadata Consistency: 0.385 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 10
#    Avg Cluster Size: 200.0
#    Largest Cluster Size: 325
#    Smallest Cluster Size: 102
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 11 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.4 → normalized: 0.044
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_11_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.227
#
# 📋 Component Breakdown:
#    Content Similarity: 0.044 (weight: 0.4, contribution: 0.017)
#    User Engagement: 0.183 (weight: 0.3, contribution: 0.055)
#    Size Balance: 0.582 (weight: 0.2, contribution: 0.116)
#    Metadata Consistency: 0.386 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 11
#    Avg Cluster Size: 181.8181818181818
#    Largest Cluster Size: 325
#    Smallest Cluster Size: 79
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 12 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.036
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_12_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.236
#
# 📋 Component Breakdown:
#    Content Similarity: 0.036 (weight: 0.4, contribution: 0.015)
#    User Engagement: 0.171 (weight: 0.3, contribution: 0.051)
#    Size Balance: 0.659 (weight: 0.2, contribution: 0.132)
#    Metadata Consistency: 0.387 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 12
#    Avg Cluster Size: 166.66666666666666
#    Largest Cluster Size: 247
#    Smallest Cluster Size: 79
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 13 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.039
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_13_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.222
#
# 📋 Component Breakdown:
#    Content Similarity: 0.039 (weight: 0.4, contribution: 0.016)
#    User Engagement: 0.166 (weight: 0.3, contribution: 0.050)
#    Size Balance: 0.592 (weight: 0.2, contribution: 0.118)
#    Metadata Consistency: 0.387 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 13
#    Avg Cluster Size: 153.84615384615384
#    Largest Cluster Size: 247
#    Smallest Cluster Size: 70
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 14 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.038
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_14_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.223
#
# 📋 Component Breakdown:
#    Content Similarity: 0.038 (weight: 0.4, contribution: 0.015)
#    User Engagement: 0.154 (weight: 0.3, contribution: 0.046)
#    Size Balance: 0.615 (weight: 0.2, contribution: 0.123)
#    Metadata Consistency: 0.387 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 14
#    Avg Cluster Size: 142.85714285714286
#    Largest Cluster Size: 239
#    Smallest Cluster Size: 70
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 15 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.034
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_15_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.221
#
# 📋 Component Breakdown:
#    Content Similarity: 0.034 (weight: 0.4, contribution: 0.013)
#    User Engagement: 0.153 (weight: 0.3, contribution: 0.046)
#    Size Balance: 0.614 (weight: 0.2, contribution: 0.123)
#    Metadata Consistency: 0.389 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 15
#    Avg Cluster Size: 133.33333333333334
#    Largest Cluster Size: 239
#    Smallest Cluster Size: 68
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 16 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.033
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_16_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.230
#
# 📋 Component Breakdown:
#    Content Similarity: 0.033 (weight: 0.4, contribution: 0.013)
#    User Engagement: 0.145 (weight: 0.3, contribution: 0.044)
#    Size Balance: 0.671 (weight: 0.2, contribution: 0.134)
#    Metadata Consistency: 0.388 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 16
#    Avg Cluster Size: 125.0
#    Largest Cluster Size: 225
#    Smallest Cluster Size: 68
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 17 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.033
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_17_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.243
#
# 📋 Component Breakdown:
#    Content Similarity: 0.033 (weight: 0.4, contribution: 0.013)
#    User Engagement: 0.143 (weight: 0.3, contribution: 0.043)
#    Size Balance: 0.740 (weight: 0.2, contribution: 0.148)
#    Metadata Consistency: 0.387 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 17
#    Avg Cluster Size: 117.6470588235294
#    Largest Cluster Size: 176
#    Smallest Cluster Size: 68
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 18 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.2 → normalized: 0.029
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_18_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.236
#
# 📋 Component Breakdown:
#    Content Similarity: 0.029 (weight: 0.4, contribution: 0.012)
#    User Engagement: 0.143 (weight: 0.3, contribution: 0.043)
#    Size Balance: 0.713 (weight: 0.2, contribution: 0.143)
#    Metadata Consistency: 0.388 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 18
#    Avg Cluster Size: 111.11111111111111
#    Largest Cluster Size: 176
#    Smallest Cluster Size: 68
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 19 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.2 → normalized: 0.027
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_19_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.230
#
# 📋 Component Breakdown:
#    Content Similarity: 0.027 (weight: 0.4, contribution: 0.011)
#    User Engagement: 0.140 (weight: 0.3, contribution: 0.042)
#    Size Balance: 0.693 (weight: 0.2, contribution: 0.139)
#    Metadata Consistency: 0.390 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 19
#    Avg Cluster Size: 105.26315789473684
#    Largest Cluster Size: 176
#    Smallest Cluster Size: 53
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 1 clusters
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_1_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.337
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.373 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 1
#    Avg Cluster Size: 2000.0
#    Largest Cluster Size: 2000
#    Smallest Cluster Size: 2000
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 20 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.2 → normalized: 0.024
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_20_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.223
#
# 📋 Component Breakdown:
#    Content Similarity: 0.024 (weight: 0.4, contribution: 0.009)
#    User Engagement: 0.137 (weight: 0.3, contribution: 0.041)
#    Size Balance: 0.667 (weight: 0.2, contribution: 0.133)
#    Metadata Consistency: 0.392 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 20
#    Avg Cluster Size: 100.0
#    Largest Cluster Size: 176
#    Smallest Cluster Size: 53
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 21 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.2 → normalized: 0.022
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_21_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.219
#
# 📋 Component Breakdown:
#    Content Similarity: 0.022 (weight: 0.4, contribution: 0.009)
#    User Engagement: 0.136 (weight: 0.3, contribution: 0.041)
#    Size Balance: 0.648 (weight: 0.2, contribution: 0.130)
#    Metadata Consistency: 0.391 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 21
#    Avg Cluster Size: 95.23809523809524
#    Largest Cluster Size: 176
#    Smallest Cluster Size: 53
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 22 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.1 → normalized: 0.020
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_22_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.218
#
# 📋 Component Breakdown:
#    Content Similarity: 0.020 (weight: 0.4, contribution: 0.008)
#    User Engagement: 0.135 (weight: 0.3, contribution: 0.040)
#    Size Balance: 0.651 (weight: 0.2, contribution: 0.130)
#    Metadata Consistency: 0.392 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 22
#    Avg Cluster Size: 90.9090909090909
#    Largest Cluster Size: 176
#    Smallest Cluster Size: 53
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 23 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.1 → normalized: 0.017
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_23_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.223
#
# 📋 Component Breakdown:
#    Content Similarity: 0.017 (weight: 0.4, contribution: 0.007)
#    User Engagement: 0.135 (weight: 0.3, contribution: 0.040)
#    Size Balance: 0.682 (weight: 0.2, contribution: 0.136)
#    Metadata Consistency: 0.393 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 23
#    Avg Cluster Size: 86.95652173913044
#    Largest Cluster Size: 176
#    Smallest Cluster Size: 53
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 24 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.2 → normalized: 0.022
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_24_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.240
#
# 📋 Component Breakdown:
#    Content Similarity: 0.022 (weight: 0.4, contribution: 0.009)
#    User Engagement: 0.131 (weight: 0.3, contribution: 0.039)
#    Size Balance: 0.762 (weight: 0.2, contribution: 0.152)
#    Metadata Consistency: 0.394 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 24
#    Avg Cluster Size: 83.33333333333333
#    Largest Cluster Size: 123
#    Smallest Cluster Size: 53
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 25 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.2 → normalized: 0.023
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_25_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.235
#
# 📋 Component Breakdown:
#    Content Similarity: 0.023 (weight: 0.4, contribution: 0.009)
#    User Engagement: 0.129 (weight: 0.3, contribution: 0.039)
#    Size Balance: 0.739 (weight: 0.2, contribution: 0.148)
#    Metadata Consistency: 0.395 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 25
#    Avg Cluster Size: 80.0
#    Largest Cluster Size: 123
#    Smallest Cluster Size: 50
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 2 clusters
#    ✅ DBCV calculated successfully: -0.854
#    📊 Using DBCV score: -0.854
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_2_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.248
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 0.703 (weight: 0.3, contribution: 0.211)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.374 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 2
#    Avg Cluster Size: 1000.0
#    Largest Cluster Size: 1450
#    Smallest Cluster Size: 550
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 3 clusters
#    ✅ DBCV calculated successfully: -0.906
#    📊 Using DBCV score: -0.906
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_3_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.206
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 0.561 (weight: 0.3, contribution: 0.168)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.374 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 3
#    Avg Cluster Size: 666.6666666666666
#    Largest Cluster Size: 1280
#    Smallest Cluster Size: 170
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 4 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.036
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_4_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.268
#
# 📋 Component Breakdown:
#    Content Similarity: 0.036 (weight: 0.4, contribution: 0.014)
#    User Engagement: 0.355 (weight: 0.3, contribution: 0.107)
#    Size Balance: 0.549 (weight: 0.2, contribution: 0.110)
#    Metadata Consistency: 0.376 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 4
#    Avg Cluster Size: 500.0
#    Largest Cluster Size: 672
#    Smallest Cluster Size: 170
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 5 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.2 → normalized: 0.029
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_5_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.224
#
# 📋 Component Breakdown:
#    Content Similarity: 0.029 (weight: 0.4, contribution: 0.011)
#    User Engagement: 0.331 (weight: 0.3, contribution: 0.099)
#    Size Balance: 0.376 (weight: 0.2, contribution: 0.075)
#    Metadata Consistency: 0.383 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 5
#    Avg Cluster Size: 400.0
#    Largest Cluster Size: 672
#    Smallest Cluster Size: 102
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 6 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.043
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_6_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.231
#
# 📋 Component Breakdown:
#    Content Similarity: 0.043 (weight: 0.4, contribution: 0.017)
#    User Engagement: 0.275 (weight: 0.3, contribution: 0.083)
#    Size Balance: 0.465 (weight: 0.2, contribution: 0.093)
#    Metadata Consistency: 0.383 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 6
#    Avg Cluster Size: 333.3333333333333
#    Largest Cluster Size: 550
#    Smallest Cluster Size: 102
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 7 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.4 → normalized: 0.045
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_7_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.236
#
# 📋 Component Breakdown:
#    Content Similarity: 0.045 (weight: 0.4, contribution: 0.018)
#    User Engagement: 0.244 (weight: 0.3, contribution: 0.073)
#    Size Balance: 0.530 (weight: 0.2, contribution: 0.106)
#    Metadata Consistency: 0.383 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 7
#    Avg Cluster Size: 285.7142857142857
#    Largest Cluster Size: 506
#    Smallest Cluster Size: 102
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 8 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.036
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_8_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.237
#
# 📋 Component Breakdown:
#    Content Similarity: 0.036 (weight: 0.4, contribution: 0.014)
#    User Engagement: 0.221 (weight: 0.3, contribution: 0.066)
#    Size Balance: 0.589 (weight: 0.2, contribution: 0.118)
#    Metadata Consistency: 0.383 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 8
#    Avg Cluster Size: 250.0
#    Largest Cluster Size: 368
#    Smallest Cluster Size: 102
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 9 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.033
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_complete_9_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.229
#
# 📋 Component Breakdown:
#    Content Similarity: 0.033 (weight: 0.4, contribution: 0.013)
#    User Engagement: 0.202 (weight: 0.3, contribution: 0.061)
#    Size Balance: 0.586 (weight: 0.2, contribution: 0.117)
#    Metadata Consistency: 0.384 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 9
#    Avg Cluster Size: 222.22222222222223
#    Largest Cluster Size: 359
#    Smallest Cluster Size: 102
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 1 clusters
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_DBSCAN-epsilon=0.04-cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.337
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.373 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 1
#    Avg Cluster Size: 2000.0
#    Largest Cluster Size: 2000
#    Smallest Cluster Size: 2000
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 1 clusters
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_DBSCAN-epsilon=0.08-cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.337
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.373 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 1
#    Avg Cluster Size: 2000.0
#    Largest Cluster Size: 2000
#    Smallest Cluster Size: 2000
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 1 clusters
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_DBSCAN-epsilon=0.12-cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.337
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.373 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 1
#    Avg Cluster Size: 2000.0
#    Largest Cluster Size: 2000
#    Smallest Cluster Size: 2000
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 1 clusters
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_DBSCAN-epsilon=0.16-cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.337
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.373 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 1
#    Avg Cluster Size: 2000.0
#    Largest Cluster Size: 2000
#    Smallest Cluster Size: 2000
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 1 clusters
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_DBSCAN-epsilon=0.20-cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.337
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.373 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 1
#    Avg Cluster Size: 2000.0
#    Largest Cluster Size: 2000
#    Smallest Cluster Size: 2000
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 1 clusters
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_DBSCAN-epsilon=0.24-cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.337
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.373 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 1
#    Avg Cluster Size: 2000.0
#    Largest Cluster Size: 2000
#    Smallest Cluster Size: 2000
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 1 clusters
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_DBSCAN-epsilon=0.28-cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.337
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.373 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 1
#    Avg Cluster Size: 2000.0
#    Largest Cluster Size: 2000
#    Smallest Cluster Size: 2000
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 1 clusters
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_DBSCAN-epsilon=0.32-cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.337
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.373 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 1
#    Avg Cluster Size: 2000.0
#    Largest Cluster Size: 2000
#    Smallest Cluster Size: 2000
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 1 clusters
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_DBSCAN-epsilon=0.36-cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.337
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.373 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 1
#    Avg Cluster Size: 2000.0
#    Largest Cluster Size: 2000
#    Smallest Cluster Size: 2000
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 2 clusters
#    ✅ DBCV calculated successfully: -0.653
#    📊 Using DBCV score: -0.653
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_DBSCAN-epsilon=0.40-cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.348
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.477 (weight: 0.1, contribution: 0.048)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 2
#    Avg Cluster Size: 1000.0
#    Largest Cluster Size: 1995
#    Smallest Cluster Size: 5
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 3 clusters
#    ✅ DBCV calculated successfully: -0.651
#    📊 Using DBCV score: -0.651
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_DBSCAN-epsilon=0.44-cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.349
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.487 (weight: 0.1, contribution: 0.049)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 3
#    Avg Cluster Size: 666.6666666666666
#    Largest Cluster Size: 1990
#    Smallest Cluster Size: 5
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 3 clusters
#    ✅ DBCV calculated successfully: -0.667
#    📊 Using DBCV score: -0.667
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_DBSCAN-epsilon=0.48-cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.339
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.391 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 3
#    Avg Cluster Size: 666.6666666666666
#    Largest Cluster Size: 1979
#    Smallest Cluster Size: 10
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 1 clusters
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_DBSCAN-epsilon=0.50-euclidean.csv
# ...
#    Largest Cluster Size: 211
#    Smallest Cluster Size: 86
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 15 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.040
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_15_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.240
#
# 📋 Component Breakdown:
#    Content Similarity: 0.040 (weight: 0.4, contribution: 0.016)
#    User Engagement: 0.154 (weight: 0.3, contribution: 0.046)
#    Size Balance: 0.694 (weight: 0.2, contribution: 0.139)
#    Metadata Consistency: 0.387 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 15
#    Avg Cluster Size: 133.33333333333334
#    Largest Cluster Size: 210
#    Smallest Cluster Size: 86
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 16 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.036
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_16_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.243
#
# 📋 Component Breakdown:
#    Content Similarity: 0.036 (weight: 0.4, contribution: 0.015)
#    User Engagement: 0.152 (weight: 0.3, contribution: 0.046)
#    Size Balance: 0.721 (weight: 0.2, contribution: 0.144)
#    Metadata Consistency: 0.387 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 16
#    Avg Cluster Size: 125.0
#    Largest Cluster Size: 193
#    Smallest Cluster Size: 86
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 17 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.033
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_17_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.244
#
# 📋 Component Breakdown:
#    Content Similarity: 0.033 (weight: 0.4, contribution: 0.013)
#    User Engagement: 0.145 (weight: 0.3, contribution: 0.043)
#    Size Balance: 0.744 (weight: 0.2, contribution: 0.149)
#    Metadata Consistency: 0.388 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 17
#    Avg Cluster Size: 117.6470588235294
#    Largest Cluster Size: 187
#    Smallest Cluster Size: 85
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 18 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.2 → normalized: 0.029
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_18_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.231
#
# 📋 Component Breakdown:
#    Content Similarity: 0.029 (weight: 0.4, contribution: 0.012)
#    User Engagement: 0.143 (weight: 0.3, contribution: 0.043)
#    Size Balance: 0.686 (weight: 0.2, contribution: 0.137)
#    Metadata Consistency: 0.390 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 18
#    Avg Cluster Size: 111.11111111111111
#    Largest Cluster Size: 187
#    Smallest Cluster Size: 53
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 19 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.2 → normalized: 0.030
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_19_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.223
#
# 📋 Component Breakdown:
#    Content Similarity: 0.030 (weight: 0.4, contribution: 0.012)
#    User Engagement: 0.137 (weight: 0.3, contribution: 0.041)
#    Size Balance: 0.654 (weight: 0.2, contribution: 0.131)
#    Metadata Consistency: 0.388 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 19
#    Avg Cluster Size: 105.26315789473684
#    Largest Cluster Size: 187
#    Smallest Cluster Size: 35
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 1 clusters
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_1_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.337
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 1.000 (weight: 0.3, contribution: 0.300)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.373 (weight: 0.1, contribution: 0.037)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 1
#    Avg Cluster Size: 2000.0
#    Largest Cluster Size: 2000
#    Smallest Cluster Size: 2000
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 20 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.033
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_20_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.216
#
# 📋 Component Breakdown:
#    Content Similarity: 0.033 (weight: 0.4, contribution: 0.013)
#    User Engagement: 0.136 (weight: 0.3, contribution: 0.041)
#    Size Balance: 0.617 (weight: 0.2, contribution: 0.123)
#    Metadata Consistency: 0.390 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 20
#    Avg Cluster Size: 100.0
#    Largest Cluster Size: 187
#    Smallest Cluster Size: 35
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 21 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.034
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_21_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.209
#
# 📋 Component Breakdown:
#    Content Similarity: 0.034 (weight: 0.4, contribution: 0.014)
#    User Engagement: 0.134 (weight: 0.3, contribution: 0.040)
#    Size Balance: 0.582 (weight: 0.2, contribution: 0.116)
#    Metadata Consistency: 0.391 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 21
#    Avg Cluster Size: 95.23809523809524
#    Largest Cluster Size: 187
#    Smallest Cluster Size: 35
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 22 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.2 → normalized: 0.031
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_22_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.203
#
# 📋 Component Breakdown:
#    Content Similarity: 0.031 (weight: 0.4, contribution: 0.012)
#    User Engagement: 0.132 (weight: 0.3, contribution: 0.040)
#    Size Balance: 0.560 (weight: 0.2, contribution: 0.112)
#    Metadata Consistency: 0.391 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 22
#    Avg Cluster Size: 90.9090909090909
#    Largest Cluster Size: 187
#    Smallest Cluster Size: 35
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 23 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.2 → normalized: 0.028
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_23_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.198
#
# 📋 Component Breakdown:
#    Content Similarity: 0.028 (weight: 0.4, contribution: 0.011)
#    User Engagement: 0.130 (weight: 0.3, contribution: 0.039)
#    Size Balance: 0.541 (weight: 0.2, contribution: 0.108)
#    Metadata Consistency: 0.392 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 23
#    Avg Cluster Size: 86.95652173913044
#    Largest Cluster Size: 187
#    Smallest Cluster Size: 35
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 24 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.2 → normalized: 0.025
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_24_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.202
#
# 📋 Component Breakdown:
#    Content Similarity: 0.025 (weight: 0.4, contribution: 0.010)
#    User Engagement: 0.127 (weight: 0.3, contribution: 0.038)
#    Size Balance: 0.572 (weight: 0.2, contribution: 0.114)
#    Metadata Consistency: 0.392 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 24
#    Avg Cluster Size: 83.33333333333333
#    Largest Cluster Size: 187
#    Smallest Cluster Size: 35
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 25 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.036
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_25_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.222
#
# 📋 Component Breakdown:
#    Content Similarity: 0.036 (weight: 0.4, contribution: 0.014)
#    User Engagement: 0.125 (weight: 0.3, contribution: 0.038)
#    Size Balance: 0.653 (weight: 0.2, contribution: 0.131)
#    Metadata Consistency: 0.392 (weight: 0.1, contribution: 0.039)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 25
#    Avg Cluster Size: 80.0
#    Largest Cluster Size: 138
#    Smallest Cluster Size: 35
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 2 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.0 → normalized: 0.000
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_2_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.286
#
# 📋 Component Breakdown:
#    Content Similarity: 0.000 (weight: 0.4, contribution: 0.000)
#    User Engagement: 0.826 (weight: 0.3, contribution: 0.248)
#    Size Balance: 0.000 (weight: 0.2, contribution: 0.000)
#    Metadata Consistency: 0.381 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 2
#    Avg Cluster Size: 1000.0
#    Largest Cluster Size: 1707
#    Smallest Cluster Size: 293
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 3 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.8 → normalized: 0.083
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_3_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.243
#
# 📋 Component Breakdown:
#    Content Similarity: 0.083 (weight: 0.4, contribution: 0.033)
#    User Engagement: 0.514 (weight: 0.3, contribution: 0.154)
#    Size Balance: 0.090 (weight: 0.2, contribution: 0.018)
#    Metadata Consistency: 0.379 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 3
#    Avg Cluster Size: 666.6666666666666
#    Largest Cluster Size: 1100
#    Smallest Cluster Size: 293
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 4 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.4 → normalized: 0.051
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_4_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.299
#
# 📋 Component Breakdown:
#    Content Similarity: 0.051 (weight: 0.4, contribution: 0.020)
#    User Engagement: 0.363 (weight: 0.3, contribution: 0.109)
#    Size Balance: 0.660 (weight: 0.2, contribution: 0.132)
#    Metadata Consistency: 0.379 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 4
#    Avg Cluster Size: 500.0
#    Largest Cluster Size: 667
#    Smallest Cluster Size: 293
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 5 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.4 → normalized: 0.046
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_5_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.276
#
# 📋 Component Breakdown:
#    Content Similarity: 0.046 (weight: 0.4, contribution: 0.018)
#    User Engagement: 0.293 (weight: 0.3, contribution: 0.088)
#    Size Balance: 0.660 (weight: 0.2, contribution: 0.132)
#    Metadata Consistency: 0.379 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 5
#    Avg Cluster Size: 400.0
#    Largest Cluster Size: 607
#    Smallest Cluster Size: 263
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 6 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.6 → normalized: 0.070
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_6_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.241
#
# 📋 Component Breakdown:
#    Content Similarity: 0.070 (weight: 0.4, contribution: 0.028)
#    User Engagement: 0.283 (weight: 0.3, contribution: 0.085)
#    Size Balance: 0.450 (weight: 0.2, contribution: 0.090)
#    Metadata Consistency: 0.381 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 6
#    Avg Cluster Size: 333.3333333333333
#    Largest Cluster Size: 607
#    Smallest Cluster Size: 106
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 7 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.5 → normalized: 0.055
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_7_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.220
#
# 📋 Component Breakdown:
#    Content Similarity: 0.055 (weight: 0.4, contribution: 0.022)
#    User Engagement: 0.258 (weight: 0.3, contribution: 0.077)
#    Size Balance: 0.412 (weight: 0.2, contribution: 0.082)
#    Metadata Consistency: 0.383 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 7
#    Avg Cluster Size: 285.7142857142857
#    Largest Cluster Size: 607
#    Smallest Cluster Size: 106
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 8 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.4 → normalized: 0.047
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_8_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.249
#
# 📋 Component Breakdown:
#    Content Similarity: 0.047 (weight: 0.4, contribution: 0.019)
#    User Engagement: 0.221 (weight: 0.3, contribution: 0.066)
#    Size Balance: 0.628 (weight: 0.2, contribution: 0.126)
#    Metadata Consistency: 0.382 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 8
#    Avg Cluster Size: 250.0
#    Largest Cluster Size: 404
#    Smallest Cluster Size: 106
# 📊 Loading data files...
# ✅ Loaded 2000 anime across 9 clusters
#    ⚠️ DBCV: Invalid result returned
#    📊 Using Calinski-Harabasz score: 1.3 → normalized: 0.036
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR Clustering_weighted_9_cosine.csv
# ==================================================
#
# 🎯 Final Fidelity Score: 0.254
#
# 📋 Component Breakdown:
#    Content Similarity: 0.036 (weight: 0.4, contribution: 0.014)
#    User Engagement: 0.201 (weight: 0.3, contribution: 0.060)
#    Size Balance: 0.704 (weight: 0.2, contribution: 0.141)
#    Metadata Consistency: 0.383 (weight: 0.1, contribution: 0.038)
#
# 📊 Cluster Statistics:
#    Total Anime: 2000
#    Num Clusters: 9
#    Avg Cluster Size: 222.22222222222223
#    Largest Cluster Size: 348
#    Smallest Cluster Size: 106
#
# ==================================================
# 🏆 HIGHEST FIDELITY SCORE: 0.383
#    Path: ClustringSVDResults\Clustering_DBSCAN-epsilon=10.00-euclidean.csv
# ==================================================
