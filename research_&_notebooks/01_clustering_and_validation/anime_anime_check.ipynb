# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('../data/anime_anime.csv')

# %%
df.head()
# Out:
#    animeA  animeB  recommendation recommendation_url  num_recommenders
# 0   20955   16371               0                NaN               NaN  \
# 1   40761   10087               0                NaN               NaN
# 2   31675   20583               0                NaN               NaN
# 3   33455   40716               0                NaN               NaN
# 4   37980   35843               0                NaN               NaN
#
#    related relation_type
# 0        1         Other
# 1        1         Other
# 2        1         Other
# 3        1         Other
# 4        1         Other

# %%
freq_table = df['num_recommenders'].value_counts()

print(freq_table)
# Out:
# num_recommenders
# 2.0      72718
# 3.0       4556
# 4.0       2432
# 5.0       1596
# 6.0       1044
#          ...
# 73.0         2
# 61.0         2
# 71.0         2
# 70.0         2
# 175.0        2
# Name: count, Length: 93, dtype: int64

# %%
freq_table.to_csv('../data/anime_anime_freq_table.csv', index=True, header=True)
