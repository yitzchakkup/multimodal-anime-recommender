# %%
import pandas as pd
import numpy as np
from scipy.stats import entropy
from collections import Counter
import os
import re
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
animes_path = r'..\data\anime.csv'
relations_path = r'..\data\anime_anime.csv'
clusters_path = r'..\data\review_clustering'
clusters_file_type = '.csv'


structural_weight = 0.5
recommendation_weight = 0.5

size_weight = 0.4
relation_weight = 0.3
metadata_weight = 0.3

# %%
cluster_files = []
for filename in os.listdir(clusters_path):
    if filename.endswith(clusters_file_type):
        cluster_files.append(filename)

# %%
def calculate_cluster_fidelity(cluster_csv_path, anime_anime_csv_path, anime_csv_path,
                             structural_weight=0.7, recommendation_weight=0.3,
                             size_weight=0.3, relation_weight=0.4, metadata_weight=0.3):
    """
    Calculate cluster fidelity score based on size balance, relation consistency, and metadata purity.
    
    Parameters:
    - cluster_csv_path: Path to CSV with columns "anime_id,cluster"
    - anime_anime_csv_path: Path to anime relations CSV
    - anime_csv_path: Path to anime metadata CSV
    - structural_weight: Weight for structural relations (sequel/prequel) in relation consistency
    - recommendation_weight: Weight for user recommendations in relation consistency
    - size_weight: Weight for size balance in composite score
    - relation_weight: Weight for relation consistency in composite score
    - metadata_weight: Weight for metadata purity in composite score
    
    Returns:
    - dict with individual scores and composite fidelity score
    """
    
    # Load data
    cluster_df = pd.read_csv(cluster_csv_path)
    anime_anime_df = pd.read_csv(anime_anime_csv_path)
    anime_df = pd.read_csv(anime_csv_path)
    
    # Create anime_id to cluster mapping
    anime_to_cluster = dict(zip(cluster_df['anime_id'], cluster_df['cluster']))
    cluster_labels = cluster_df['cluster'].values
    
    # 1. Size Balance (entropy of cluster sizes)
    unique, counts = np.unique(cluster_labels, return_counts=True)
    probabilities = counts / len(cluster_labels)
    # Normalize entropy to [0,1] range
    max_possible_entropy = np.log(len(unique))  # Maximum entropy occurs when all clusters are equal size
    size_balance = entropy(probabilities) / max_possible_entropy if max_possible_entropy > 0 else 0.0
    
    # 2. Relation Consistency (both structural and recommendations)
    
    # 2a. Structural Relations
    structural_relations = ['Sequel', 'Prequel', 'Spin-off', 'Side story', 
                           'Parent story', 'Alternative version', 'Full story',
                           'Character', 'Alternative setting', 'Summary']
    
    structural_pairs = anime_anime_df[
        (anime_anime_df['related'] == 1) &
        (anime_anime_df['relation_type'].isin(structural_relations))
    ]
    
    structural_consistent = 0
    structural_total = 0
    
    for _, row in structural_pairs.iterrows():
        anime_a, anime_b = row['animeA'], row['animeB']
        
        if anime_a not in anime_to_cluster or anime_b not in anime_to_cluster:
            continue
            
        structural_total += 1
        if anime_to_cluster[anime_a] == anime_to_cluster[anime_b]:
            structural_consistent += 1
    
    structural_consistency = structural_consistent / structural_total if structural_total > 0 else 0.0
    
    # 2b. User Recommendations (weighted by number of recommenders)
    recommendation_pairs = anime_anime_df[anime_anime_df['recommendation'] == 1]

    recommendation_weighted_same = 0.0
    recommendation_total_weight = 0.0
    recommendation_pairs_count = 0

    for _, row in recommendation_pairs.iterrows():
        anime_a, anime_b = row['animeA'], row['animeB']
    
        if anime_a not in anime_to_cluster or anime_b not in anime_to_cluster:
            continue
        
        recommendation_pairs_count += 1
        # Weight by number of recommenders (log scale to prevent extreme values)
        weight = np.log(row['num_recommenders'] + 1) if pd.notna(row['num_recommenders']) else 1.0
        recommendation_total_weight += weight
        
        if anime_to_cluster[anime_a] == anime_to_cluster[anime_b]:
            recommendation_weighted_same += weight

    recommendation_consistency = recommendation_weighted_same / recommendation_total_weight if recommendation_total_weight > 0 else 0.0
    
    # Combined relation consistency
    if structural_total > 0 and recommendation_pairs_count > 0:
        relation_consistency = (structural_weight * structural_consistency + 
                               recommendation_weight * recommendation_consistency)
    elif structural_total > 0:
        relation_consistency = structural_consistency
    elif recommendation_pairs_count > 0:
        relation_consistency = recommendation_consistency
    else:
        relation_consistency = 0.0
    
    # 3. Metadata Purity
    def calculate_metadata_purity(column):
        cluster_purities = []
        
        for cluster_id in np.unique(cluster_labels):
            # Get anime in this cluster
            cluster_anime = [aid for aid, cid in anime_to_cluster.items() if cid == cluster_id]
            
            if len(cluster_anime) < 2:  # Need at least 2 items
                continue
                
            # Get metadata for these anime
            cluster_metadata = anime_df[anime_df['anime_id'].isin(cluster_anime)][column].dropna()
            
            if len(cluster_metadata) == 0:
                continue
            
            # Handle pipe-separated values (like "Action|Adventure")
            all_values = []
            for meta in cluster_metadata:
                if pd.isna(meta):
                    continue
                if '|' in str(meta):
                    all_values.extend(str(meta).split('|'))
                else:
                    all_values.append(str(meta))
            
            if not all_values:
                continue
                
            # Calculate purity as most common value frequency
            value_counts = Counter(all_values)
            most_common_count = value_counts.most_common(1)[0][1]
            purity = most_common_count / len(all_values)
            cluster_purities.append(purity)
        
        return np.mean(cluster_purities) if cluster_purities else 0.0
    
    # Calculate purity for available metadata columns
    purity_scores = {}
    if 'genres' in anime_df.columns:
        purity_scores['genre_purity'] = calculate_metadata_purity('genres')
    if 'studios' in anime_df.columns:
        purity_scores['studio_purity'] = calculate_metadata_purity('studios')
    if 'type' in anime_df.columns:
        purity_scores['type_purity'] = calculate_metadata_purity('type')
    
    # Average metadata purity
    metadata_purity = np.mean(list(purity_scores.values())) if purity_scores else 0.0
    
    # Composite fidelity score with custom weights
    composite_fidelity = (relation_weight * relation_consistency + 
                         size_weight * size_balance + 
                         metadata_weight * metadata_purity)
    
    return {
        'size_balance': size_balance,
        'structural_consistency': structural_consistency,
        'recommendation_consistency': recommendation_consistency,
        'relation_consistency': relation_consistency,
        'metadata_purity': metadata_purity,
        'metadata_breakdown': purity_scores,
        'composite_fidelity': composite_fidelity,
        'structural_pairs_evaluated': structural_total,
        'recommendation_pairs_evaluated': recommendation_pairs_count  
    }

# %%
# Store results: {method: [(num_clusters, metrics_dict), ...]}
results_by_method = defaultdict(list)

for file in cluster_files:    
    cluster_file_path = os.path.join(clusters_path, file)
    result = calculate_cluster_fidelity(
        cluster_file_path,
        relations_path,
        animes_path,
        structural_weight=structural_weight,
        recommendation_weight=recommendation_weight,
        size_weight=size_weight,
        relation_weight=relation_weight,
        metadata_weight=metadata_weight
    )
    
    # Extract method and cluster count from filename
    match = re.match(r"([a-zA-Z_0-9]+)_(\d+)_clusters\.csv$", file)
    if match:
        method = match.group(1)
        num_clusters = int(match.group(2))
        
        # Store all base metrics (no composite fidelity)
        results_by_method[method].append((
            num_clusters,
            {
                "size_balance": result['size_balance'],
                "structural_consistency": result['structural_consistency'],
                "structural_pairs_evaluated": result['structural_pairs_evaluated'],
                "recommendation_consistency": result['recommendation_consistency'],
                "recommendation_pairs_evaluated": result['recommendation_pairs_evaluated'],
                "relation_consistency": result['relation_consistency'],
                "metadata_purity": result['metadata_purity'],
                "metadata_breakdown": result['metadata_breakdown'],
            }
        ))
    
    # 🔹 Preserve all the printouts from before
    print("\n" + "="*50)
    print(f"📊 CLUSTERING FIDELITY RESULTS FOR {file}" )
    print("="*50)
    print(f"Size Balance (Entropy): {result['size_balance']:.3f}")
    print(f"Structural Consistency: {result['structural_consistency']:.3f} ({result['structural_pairs_evaluated']} pairs)")
    print(f"Recommendation Consistency: {result['recommendation_consistency']:.3f} ({result['recommendation_pairs_evaluated']} pairs)")
    print(f"Combined Relation Consistency: {result['relation_consistency']:.3f}")
    print(f"Metadata Purity: {result['metadata_purity']:.3f}")
    if result['metadata_breakdown']:
        for meta_type, score in result['metadata_breakdown'].items():
            print(f"  └─ {meta_type}: {score:.3f}")
    print(f"Original Composite Fidelity (from function): {result['composite_fidelity']:.3f}")
# Out:
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR hierarchical_ward_10_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.943
# Structural Consistency: 0.363 (7689 pairs)
# Recommendation Consistency: 0.257 (46260 pairs)
# Combined Relation Consistency: 0.310
# Metadata Purity: 0.314
#   └─ genre_purity: 0.130
#   └─ studio_purity: 0.106
#   └─ type_purity: 0.707
# Original Composite Fidelity (from function): 0.501
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR hierarchical_ward_11_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.938
# Structural Consistency: 0.356 (7689 pairs)
# Recommendation Consistency: 0.238 (46260 pairs)
# Combined Relation Consistency: 0.297
# Metadata Purity: 0.312
#   └─ genre_purity: 0.130
#   └─ studio_purity: 0.110
#   └─ type_purity: 0.696
# Original Composite Fidelity (from function): 0.494
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR hierarchical_ward_12_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.936
# Structural Consistency: 0.308 (7689 pairs)
# Recommendation Consistency: 0.231 (46260 pairs)
# Combined Relation Consistency: 0.270
# Metadata Purity: 0.307
#   └─ genre_purity: 0.131
#   └─ studio_purity: 0.114
#   └─ type_purity: 0.675
# Original Composite Fidelity (from function): 0.480
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR hierarchical_ward_13_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.920
# Structural Consistency: 0.307 (7689 pairs)
# Recommendation Consistency: 0.228 (46260 pairs)
# Combined Relation Consistency: 0.268
# Metadata Purity: 0.305
#   └─ genre_purity: 0.131
#   └─ studio_purity: 0.113
#   └─ type_purity: 0.670
# Original Composite Fidelity (from function): 0.475
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR hierarchical_ward_14_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.948
# Structural Consistency: 0.300 (7689 pairs)
# Recommendation Consistency: 0.194 (46260 pairs)
# Combined Relation Consistency: 0.247
# Metadata Purity: 0.311
#   └─ genre_purity: 0.135
#   └─ studio_purity: 0.113
#   └─ type_purity: 0.685
# Original Composite Fidelity (from function): 0.476
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR hierarchical_ward_15_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.941
# Structural Consistency: 0.298 (7689 pairs)
# Recommendation Consistency: 0.192 (46260 pairs)
# Combined Relation Consistency: 0.245
# Metadata Purity: 0.312
#   └─ genre_purity: 0.133
#   └─ studio_purity: 0.112
#   └─ type_purity: 0.691
# Original Composite Fidelity (from function): 0.474
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR hierarchical_ward_16_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.928
# Structural Consistency: 0.294 (7689 pairs)
# Recommendation Consistency: 0.192 (46260 pairs)
# Combined Relation Consistency: 0.243
# Metadata Purity: 0.318
#   └─ genre_purity: 0.134
#   └─ studio_purity: 0.129
#   └─ type_purity: 0.690
# Original Composite Fidelity (from function): 0.471
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR hierarchical_ward_17_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.930
# Structural Consistency: 0.292 (7689 pairs)
# Recommendation Consistency: 0.182 (46260 pairs)
# Combined Relation Consistency: 0.237
# Metadata Purity: 0.321
#   └─ genre_purity: 0.135
#   └─ studio_purity: 0.127
#   └─ type_purity: 0.702
# Original Composite Fidelity (from function): 0.470
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR hierarchical_ward_18_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.950
# Structural Consistency: 0.276 (7689 pairs)
# Recommendation Consistency: 0.170 (46260 pairs)
# Combined Relation Consistency: 0.223
# Metadata Purity: 0.321
#   └─ genre_purity: 0.135
#   └─ studio_purity: 0.125
#   └─ type_purity: 0.703
# Original Composite Fidelity (from function): 0.470
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR hierarchical_ward_19_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.936
# Structural Consistency: 0.276 (7689 pairs)
# Recommendation Consistency: 0.170 (46260 pairs)
# Combined Relation Consistency: 0.223
# Metadata Purity: 0.338
#   └─ genre_purity: 0.157
#   └─ studio_purity: 0.138
#   └─ type_purity: 0.720
# Original Composite Fidelity (from function): 0.472
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR hierarchical_ward_20_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.929
# Structural Consistency: 0.276 (7689 pairs)
# Recommendation Consistency: 0.168 (46260 pairs)
# Combined Relation Consistency: 0.222
# Metadata Purity: 0.342
#   └─ genre_purity: 0.158
#   └─ studio_purity: 0.141
#   └─ type_purity: 0.727
# Original Composite Fidelity (from function): 0.470
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_10_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.984
# Structural Consistency: 0.335 (7689 pairs)
# Recommendation Consistency: 0.256 (46260 pairs)
# Combined Relation Consistency: 0.296
# Metadata Purity: 0.312
#   └─ genre_purity: 0.116
#   └─ studio_purity: 0.091
#   └─ type_purity: 0.729
# Original Composite Fidelity (from function): 0.507
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_11_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.994
# Structural Consistency: 0.338 (7689 pairs)
# Recommendation Consistency: 0.232 (46260 pairs)
# Combined Relation Consistency: 0.285
# Metadata Purity: 0.314
#   └─ genre_purity: 0.115
#   └─ studio_purity: 0.094
#   └─ type_purity: 0.733
# Original Composite Fidelity (from function): 0.507
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_12_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.986
# Structural Consistency: 0.338 (7689 pairs)
# Recommendation Consistency: 0.227 (46260 pairs)
# Combined Relation Consistency: 0.283
# Metadata Purity: 0.315
#   └─ genre_purity: 0.116
#   └─ studio_purity: 0.100
#   └─ type_purity: 0.728
# Original Composite Fidelity (from function): 0.503
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_13_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.987
# Structural Consistency: 0.329 (7689 pairs)
# Recommendation Consistency: 0.212 (46260 pairs)
# Combined Relation Consistency: 0.271
# Metadata Purity: 0.317
#   └─ genre_purity: 0.118
#   └─ studio_purity: 0.099
#   └─ type_purity: 0.733
# Original Composite Fidelity (from function): 0.499
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_14_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.987
# Structural Consistency: 0.326 (7689 pairs)
# Recommendation Consistency: 0.211 (46260 pairs)
# Combined Relation Consistency: 0.268
# Metadata Purity: 0.320
#   └─ genre_purity: 0.120
#   └─ studio_purity: 0.099
#   └─ type_purity: 0.743
# Original Composite Fidelity (from function): 0.500
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_15_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.991
# Structural Consistency: 0.319 (7689 pairs)
# Recommendation Consistency: 0.207 (46260 pairs)
# Combined Relation Consistency: 0.263
# Metadata Purity: 0.318
#   └─ genre_purity: 0.125
#   └─ studio_purity: 0.098
#   └─ type_purity: 0.732
# Original Composite Fidelity (from function): 0.498
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_16_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.982
# Structural Consistency: 0.320 (7689 pairs)
# Recommendation Consistency: 0.192 (46260 pairs)
# Combined Relation Consistency: 0.256
# Metadata Purity: 0.326
#   └─ genre_purity: 0.125
#   └─ studio_purity: 0.111
#   └─ type_purity: 0.741
# Original Composite Fidelity (from function): 0.495
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_17_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.991
# Structural Consistency: 0.296 (7689 pairs)
# Recommendation Consistency: 0.186 (46260 pairs)
# Combined Relation Consistency: 0.241
# Metadata Purity: 0.323
#   └─ genre_purity: 0.124
#   └─ studio_purity: 0.106
#   └─ type_purity: 0.740
# Original Composite Fidelity (from function): 0.491
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_18_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.984
# Structural Consistency: 0.266 (7689 pairs)
# Recommendation Consistency: 0.185 (46260 pairs)
# Combined Relation Consistency: 0.226
# Metadata Purity: 0.337
#   └─ genre_purity: 0.125
#   └─ studio_purity: 0.148
#   └─ type_purity: 0.738
# Original Composite Fidelity (from function): 0.487
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_19_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.991
# Structural Consistency: 0.301 (7689 pairs)
# Recommendation Consistency: 0.181 (46260 pairs)
# Combined Relation Consistency: 0.241
# Metadata Purity: 0.321
#   └─ genre_purity: 0.130
#   └─ studio_purity: 0.107
#   └─ type_purity: 0.726
# Original Composite Fidelity (from function): 0.490
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_20_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.981
# Structural Consistency: 0.263 (7689 pairs)
# Recommendation Consistency: 0.186 (46260 pairs)
# Combined Relation Consistency: 0.224
# Metadata Purity: 0.332
#   └─ genre_purity: 0.127
#   └─ studio_purity: 0.147
#   └─ type_purity: 0.722
# Original Composite Fidelity (from function): 0.484
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_pca_10_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.996
# Structural Consistency: 0.328 (7689 pairs)
# Recommendation Consistency: 0.279 (46260 pairs)
# Combined Relation Consistency: 0.303
# Metadata Purity: 0.308
#   └─ genre_purity: 0.116
#   └─ studio_purity: 0.093
#   └─ type_purity: 0.714
# Original Composite Fidelity (from function): 0.512
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_pca_11_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.997
# Structural Consistency: 0.327 (7689 pairs)
# Recommendation Consistency: 0.262 (46260 pairs)
# Combined Relation Consistency: 0.295
# Metadata Purity: 0.311
#   └─ genre_purity: 0.118
#   └─ studio_purity: 0.098
#   └─ type_purity: 0.718
# Original Composite Fidelity (from function): 0.510
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_pca_12_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.985
# Structural Consistency: 0.330 (7689 pairs)
# Recommendation Consistency: 0.269 (46260 pairs)
# Combined Relation Consistency: 0.299
# Metadata Purity: 0.313
#   └─ genre_purity: 0.118
#   └─ studio_purity: 0.110
#   └─ type_purity: 0.710
# Original Composite Fidelity (from function): 0.509
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_pca_13_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.987
# Structural Consistency: 0.327 (7689 pairs)
# Recommendation Consistency: 0.257 (46260 pairs)
# Combined Relation Consistency: 0.292
# Metadata Purity: 0.315
#   └─ genre_purity: 0.119
#   └─ studio_purity: 0.110
#   └─ type_purity: 0.714
# Original Composite Fidelity (from function): 0.507
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_pca_14_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.994
# Structural Consistency: 0.321 (7689 pairs)
# Recommendation Consistency: 0.234 (46260 pairs)
# Combined Relation Consistency: 0.278
# Metadata Purity: 0.315
#   └─ genre_purity: 0.123
#   └─ studio_purity: 0.101
#   └─ type_purity: 0.720
# Original Composite Fidelity (from function): 0.504
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_pca_15_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.990
# Structural Consistency: 0.310 (7689 pairs)
# Recommendation Consistency: 0.231 (46260 pairs)
# Combined Relation Consistency: 0.271
# Metadata Purity: 0.322
#   └─ genre_purity: 0.126
#   └─ studio_purity: 0.115
#   └─ type_purity: 0.723
# Original Composite Fidelity (from function): 0.502
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_pca_16_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.989
# Structural Consistency: 0.325 (7689 pairs)
# Recommendation Consistency: 0.222 (46260 pairs)
# Combined Relation Consistency: 0.273
# Metadata Purity: 0.315
#   └─ genre_purity: 0.123
#   └─ studio_purity: 0.112
#   └─ type_purity: 0.712
# Original Composite Fidelity (from function): 0.501
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_pca_17_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.994
# Structural Consistency: 0.319 (7689 pairs)
# Recommendation Consistency: 0.211 (46260 pairs)
# Combined Relation Consistency: 0.265
# Metadata Purity: 0.322
#   └─ genre_purity: 0.127
#   └─ studio_purity: 0.112
#   └─ type_purity: 0.726
# Original Composite Fidelity (from function): 0.501
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_pca_18_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.991
# Structural Consistency: 0.318 (7689 pairs)
# Recommendation Consistency: 0.206 (46260 pairs)
# Combined Relation Consistency: 0.262
# Metadata Purity: 0.324
#   └─ genre_purity: 0.126
#   └─ studio_purity: 0.120
#   └─ type_purity: 0.725
# Original Composite Fidelity (from function): 0.499
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_pca_19_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.993
# Structural Consistency: 0.314 (7689 pairs)
# Recommendation Consistency: 0.195 (46260 pairs)
# Combined Relation Consistency: 0.255
# Metadata Purity: 0.328
#   └─ genre_purity: 0.126
#   └─ studio_purity: 0.119
#   └─ type_purity: 0.738
# Original Composite Fidelity (from function): 0.498
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR kmeans_pca_20_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.994
# Structural Consistency: 0.312 (7689 pairs)
# Recommendation Consistency: 0.203 (46260 pairs)
# Combined Relation Consistency: 0.258
# Metadata Purity: 0.318
#   └─ genre_purity: 0.126
#   └─ studio_purity: 0.116
#   └─ type_purity: 0.713
# Original Composite Fidelity (from function): 0.497
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR rebalanced_1_20_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.200
# Structural Consistency: 0.784 (7689 pairs)
# Recommendation Consistency: 0.886 (46260 pairs)
# Combined Relation Consistency: 0.835
# Metadata Purity: 0.435
#   └─ genre_purity: 0.217
#   └─ studio_purity: 0.341
#   └─ type_purity: 0.748
# Original Composite Fidelity (from function): 0.524
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR rebalanced_2_19_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.325
# Structural Consistency: 0.943 (7689 pairs)
# Recommendation Consistency: 0.645 (46260 pairs)
# Combined Relation Consistency: 0.794
# Metadata Purity: 0.441
#   └─ genre_purity: 0.220
#   └─ studio_purity: 0.356
#   └─ type_purity: 0.748
# Original Composite Fidelity (from function): 0.548
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR rebalanced_2_20_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.321
# Structural Consistency: 0.943 (7689 pairs)
# Recommendation Consistency: 0.645 (46260 pairs)
# Combined Relation Consistency: 0.794
# Metadata Purity: 0.441
#   └─ genre_purity: 0.222
#   └─ studio_purity: 0.346
#   └─ type_purity: 0.753
# Original Composite Fidelity (from function): 0.546
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR rebalanced_3_15_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.209
# Structural Consistency: 0.790 (7689 pairs)
# Recommendation Consistency: 0.879 (46260 pairs)
# Combined Relation Consistency: 0.835
# Metadata Purity: 0.386
#   └─ genre_purity: 0.206
#   └─ studio_purity: 0.286
#   └─ type_purity: 0.664
# Original Composite Fidelity (from function): 0.512
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR rebalanced_3_16_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.227
# Structural Consistency: 0.788 (7689 pairs)
# Recommendation Consistency: 0.862 (46260 pairs)
# Combined Relation Consistency: 0.825
# Metadata Purity: 0.386
#   └─ genre_purity: 0.203
#   └─ studio_purity: 0.283
#   └─ type_purity: 0.673
# Original Composite Fidelity (from function): 0.514
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR rebalanced_3_17_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.223
# Structural Consistency: 0.788 (7689 pairs)
# Recommendation Consistency: 0.862 (46260 pairs)
# Combined Relation Consistency: 0.825
# Metadata Purity: 0.398
#   └─ genre_purity: 0.203
#   └─ studio_purity: 0.305
#   └─ type_purity: 0.685
# Original Composite Fidelity (from function): 0.516
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR rebalanced_3_18_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.220
# Structural Consistency: 0.788 (7689 pairs)
# Recommendation Consistency: 0.862 (46260 pairs)
# Combined Relation Consistency: 0.825
# Metadata Purity: 0.417
#   └─ genre_purity: 0.204
#   └─ studio_purity: 0.344
#   └─ type_purity: 0.703
# Original Composite Fidelity (from function): 0.521
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR rebalanced_3_19_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.218
# Structural Consistency: 0.788 (7689 pairs)
# Recommendation Consistency: 0.862 (46260 pairs)
# Combined Relation Consistency: 0.825
# Metadata Purity: 0.426
#   └─ genre_purity: 0.207
#   └─ studio_purity: 0.353
#   └─ type_purity: 0.719
# Original Composite Fidelity (from function): 0.523
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR rebalanced_3_20_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.216
# Structural Consistency: 0.788 (7689 pairs)
# Recommendation Consistency: 0.862 (46260 pairs)
# Combined Relation Consistency: 0.825
# Metadata Purity: 0.428
#   └─ genre_purity: 0.208
#   └─ studio_purity: 0.357
#   └─ type_purity: 0.718
# Original Composite Fidelity (from function): 0.523
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_10_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.959
# Structural Consistency: 0.491 (7689 pairs)
# Recommendation Consistency: 0.347 (46260 pairs)
# Combined Relation Consistency: 0.419
# Metadata Purity: 0.324
#   └─ genre_purity: 0.138
#   └─ studio_purity: 0.135
#   └─ type_purity: 0.698
# Original Composite Fidelity (from function): 0.552
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_11_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.965
# Structural Consistency: 0.421 (7689 pairs)
# Recommendation Consistency: 0.351 (46260 pairs)
# Combined Relation Consistency: 0.386
# Metadata Purity: 0.322
#   └─ genre_purity: 0.137
#   └─ studio_purity: 0.131
#   └─ type_purity: 0.698
# Original Composite Fidelity (from function): 0.540
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_12_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.972
# Structural Consistency: 0.426 (7689 pairs)
# Recommendation Consistency: 0.336 (46260 pairs)
# Combined Relation Consistency: 0.381
# Metadata Purity: 0.329
#   └─ genre_purity: 0.140
#   └─ studio_purity: 0.130
#   └─ type_purity: 0.717
# Original Composite Fidelity (from function): 0.543
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_13_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.981
# Structural Consistency: 0.431 (7689 pairs)
# Recommendation Consistency: 0.327 (46260 pairs)
# Combined Relation Consistency: 0.379
# Metadata Purity: 0.331
#   └─ genre_purity: 0.142
#   └─ studio_purity: 0.128
#   └─ type_purity: 0.725
# Original Composite Fidelity (from function): 0.545
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_14_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.951
# Structural Consistency: 0.474 (7689 pairs)
# Recommendation Consistency: 0.326 (46260 pairs)
# Combined Relation Consistency: 0.400
# Metadata Purity: 0.360
#   └─ genre_purity: 0.146
#   └─ studio_purity: 0.203
#   └─ type_purity: 0.731
# Original Composite Fidelity (from function): 0.553
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_15_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.932
# Structural Consistency: 0.415 (7689 pairs)
# Recommendation Consistency: 0.344 (46260 pairs)
# Combined Relation Consistency: 0.380
# Metadata Purity: 0.366
#   └─ genre_purity: 0.150
#   └─ studio_purity: 0.209
#   └─ type_purity: 0.739
# Original Composite Fidelity (from function): 0.541
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_16_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.938
# Structural Consistency: 0.444 (7689 pairs)
# Recommendation Consistency: 0.326 (46260 pairs)
# Combined Relation Consistency: 0.385
# Metadata Purity: 0.364
#   └─ genre_purity: 0.152
#   └─ studio_purity: 0.213
#   └─ type_purity: 0.726
# Original Composite Fidelity (from function): 0.545
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_17_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.942
# Structural Consistency: 0.458 (7689 pairs)
# Recommendation Consistency: 0.311 (46260 pairs)
# Combined Relation Consistency: 0.384
# Metadata Purity: 0.362
#   └─ genre_purity: 0.147
#   └─ studio_purity: 0.211
#   └─ type_purity: 0.728
# Original Composite Fidelity (from function): 0.545
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_18_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.919
# Structural Consistency: 0.480 (7689 pairs)
# Recommendation Consistency: 0.300 (46260 pairs)
# Combined Relation Consistency: 0.390
# Metadata Purity: 0.377
#   └─ genre_purity: 0.149
#   └─ studio_purity: 0.252
#   └─ type_purity: 0.728
# Original Composite Fidelity (from function): 0.545
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_19_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.925
# Structural Consistency: 0.445 (7689 pairs)
# Recommendation Consistency: 0.311 (46260 pairs)
# Combined Relation Consistency: 0.378
# Metadata Purity: 0.383
#   └─ genre_purity: 0.154
#   └─ studio_purity: 0.257
#   └─ type_purity: 0.737
# Original Composite Fidelity (from function): 0.544
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_20_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.908
# Structural Consistency: 0.510 (7689 pairs)
# Recommendation Consistency: 0.296 (46260 pairs)
# Combined Relation Consistency: 0.403
# Metadata Purity: 0.391
#   └─ genre_purity: 0.152
#   └─ studio_purity: 0.278
#   └─ type_purity: 0.743
# Original Composite Fidelity (from function): 0.551
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_robust_10_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.327
# Structural Consistency: 0.907 (7689 pairs)
# Recommendation Consistency: 0.733 (46260 pairs)
# Combined Relation Consistency: 0.820
# Metadata Purity: 0.437
#   └─ genre_purity: 0.244
#   └─ studio_purity: 0.371
#   └─ type_purity: 0.696
# Original Composite Fidelity (from function): 0.557
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_robust_11_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.329
# Structural Consistency: 0.908 (7689 pairs)
# Recommendation Consistency: 0.732 (46260 pairs)
# Combined Relation Consistency: 0.820
# Metadata Purity: 0.447
#   └─ genre_purity: 0.260
#   └─ studio_purity: 0.376
#   └─ type_purity: 0.705
# Original Composite Fidelity (from function): 0.561
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_robust_12_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.359
# Structural Consistency: 0.805 (7689 pairs)
# Recommendation Consistency: 0.733 (46260 pairs)
# Combined Relation Consistency: 0.769
# Metadata Purity: 0.439
#   └─ genre_purity: 0.253
#   └─ studio_purity: 0.374
#   └─ type_purity: 0.690
# Original Composite Fidelity (from function): 0.547
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_robust_13_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.487
# Structural Consistency: 0.645 (7689 pairs)
# Recommendation Consistency: 0.674 (46260 pairs)
# Combined Relation Consistency: 0.660
# Metadata Purity: 0.420
#   └─ genre_purity: 0.227
#   └─ studio_purity: 0.342
#   └─ type_purity: 0.693
# Original Composite Fidelity (from function): 0.536
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_robust_14_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.496
# Structural Consistency: 0.642 (7689 pairs)
# Recommendation Consistency: 0.665 (46260 pairs)
# Combined Relation Consistency: 0.654
# Metadata Purity: 0.428
#   └─ genre_purity: 0.233
#   └─ studio_purity: 0.340
#   └─ type_purity: 0.711
# Original Composite Fidelity (from function): 0.539
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_robust_15_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.504
# Structural Consistency: 0.632 (7689 pairs)
# Recommendation Consistency: 0.666 (46260 pairs)
# Combined Relation Consistency: 0.649
# Metadata Purity: 0.408
#   └─ genre_purity: 0.215
#   └─ studio_purity: 0.318
#   └─ type_purity: 0.691
# Original Composite Fidelity (from function): 0.533
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_robust_16_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.542
# Structural Consistency: 0.629 (7689 pairs)
# Recommendation Consistency: 0.616 (46260 pairs)
# Combined Relation Consistency: 0.623
# Metadata Purity: 0.411
#   └─ genre_purity: 0.221
#   └─ studio_purity: 0.306
#   └─ type_purity: 0.707
# Original Composite Fidelity (from function): 0.535
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_robust_17_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.558
# Structural Consistency: 0.594 (7689 pairs)
# Recommendation Consistency: 0.626 (46260 pairs)
# Combined Relation Consistency: 0.610
# Metadata Purity: 0.420
#   └─ genre_purity: 0.223
#   └─ studio_purity: 0.320
#   └─ type_purity: 0.718
# Original Composite Fidelity (from function): 0.537
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_robust_18_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.495
# Structural Consistency: 0.842 (7689 pairs)
# Recommendation Consistency: 0.592 (46260 pairs)
# Combined Relation Consistency: 0.717
# Metadata Purity: 0.438
#   └─ genre_purity: 0.221
#   └─ studio_purity: 0.341
#   └─ type_purity: 0.751
# Original Composite Fidelity (from function): 0.567
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_robust_19_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.492
# Structural Consistency: 0.846 (7689 pairs)
# Recommendation Consistency: 0.590 (46260 pairs)
# Combined Relation Consistency: 0.718
# Metadata Purity: 0.446
#   └─ genre_purity: 0.231
#   └─ studio_purity: 0.349
#   └─ type_purity: 0.758
# Original Composite Fidelity (from function): 0.569
#
# ==================================================
# 📊 CLUSTERING FIDELITY RESULTS FOR spectral_robust_20_clusters.csv
# ==================================================
# Size Balance (Entropy): 0.614
# Structural Consistency: 0.552 (7689 pairs)
# Recommendation Consistency: 0.530 (46260 pairs)
# Combined Relation Consistency: 0.541
# Metadata Purity: 0.443
#   └─ genre_purity: 0.234
#   └─ studio_purity: 0.347
#   └─ type_purity: 0.747
# Original Composite Fidelity (from function): 0.533

# %%
plt.figure(figsize=(8, 5))

for method, data in results_by_method.items():
    recomputed = []
    for num_clusters, metrics in data:
        composite = (
            size_weight * metrics["size_balance"]
            + relation_weight * metrics["relation_consistency"]
            + metadata_weight * metrics["metadata_purity"]
        )
        recomputed.append((num_clusters, composite))
    
    # Sort & plot
    recomputed.sort(key=lambda x: x[0])
    x_vals, y_vals = zip(*recomputed)
    plt.plot(x_vals, y_vals, marker='o', label=method)

plt.xlabel("Number of Clusters")
plt.ylabel("Composite Fidelity (Recomputed)")
plt.title("Fidelity vs Number of Clusters by Clustering Method")
plt.grid(True)

# Legend outside top-left corner
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1.0), borderaxespad=0)

plt.tight_layout()
plt.show()
